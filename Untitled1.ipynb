# %% [markdown]
# <a href="https://colab.research.google.com/github/pallavibhan/First-Contribution/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset=pd.read_excel("/content/Superstore_USA.xlsx")

# %%
dataset
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
dataset.shape
# Out:
# (9426, 24)

# %%
dataset.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   9426.000000  9426.000000  9426.000000    9426.000000  9426.000000
# mean   20241.015277     0.049628    88.303686      12.795142  1738.422236
# min        2.000000     0.000000     0.990000       0.490000     2.000000
# 25%    19330.250000     0.020000     6.480000       3.192500   898.000000
# 50%    21686.500000     0.050000    20.990000       6.050000  1750.000000
# 75%    24042.750000     0.080000    85.990000      13.990000  2578.750000
# max    26399.000000     0.250000  6783.020000     164.730000  3403.000000
# std     6101.890965     0.031798   281.540982      17.181203   979.167197
#
#        Product Base Margin   Postal Code                     Order Date  \
# count          9354.000000   9426.000000                           9426
# mean              0.512189  52446.327286  2012-03-05 18:33:59.465308672
# min               0.350000   1001.000000            2010-01-01 00:00:00
# ...

# %%
dataset["Product Base Margin"]
# Out:
# 0       0.36
# 1       0.54
# 2       0.37
# 3       0.56
# 4       0.59
#         ...
# 9421    0.40
# 9422    0.54
# 9423    0.71
# 9424    0.65
# 9425    0.38
# Name: Product Base Margin, Length: 9426, dtype: float64

# %%
dataset.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
dataset["Product Base Margin"]=dataset["Product Base Margin"].fillna(dataset["Product Base Margin"].mean())

# %%
dataset["Product Base Margin"]
# Out:
# 0       0.36
# 1       0.54
# 2       0.37
# 3       0.56
# 4       0.59
#         ...
# 9421    0.40
# 9422    0.54
# 9423    0.71
# 9424    0.65
# 9425    0.38
# Name: Product Base Margin, Length: 9426, dtype: float64

# %%
dataset.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %%
#based on priority customer which product is mostlty liked

new_var = dataset["Order Priority"].value_counts()
new_var
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Critical            1
# Name: count, dtype: int64

# %%
new_var_1 = dataset.groupby("Order Priority").count()
new_var_1

# %%
dataset['Order Priority'].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %%
dataset['Order Priority']=dataset['Order Priority'].replace('Critical ','Critical')
dataset
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
dataset["Order Priority"].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical'], dtype=object)

# %%
dataset["Order Priority"].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1805
# Name: count, dtype: int64

# %%
#Graphical analysis

# %%
t=dataset["Region"]
plt.figure(figsize=(5,3))
sns.countplot(x="Order Priority",data=dataset,palette='coolwarm',hue=t)

plt.title("Order Priority Region Wise")
plt.ylabel("Count OF Order Priority Region Wise")
plt.legend()
plt.savefig("pn.png")

# %%
dataset["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))

sns.countplot(x="Ship Mode",data=dataset,palette="bright")
plt.title(" Order Priority  as per Ship Mode")
plt.show()
# Out:
# <ipython-input-67-953f9ca856c2>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Ship Mode",data=dataset,palette="bright")

# %%
x_axis=dataset["Ship Mode"].value_counts().index
y_axis=dataset["Ship Mode"].value_counts().values
x_axis
y_axis
w=['gold', 'lightskyblue', 'lightcoral']
r=dataset["Region"]
plt.figure(figsize=(4,5))
plt.title("Ship Mode")

plt.pie(y_axis, labels=x_axis, startangle=60, autopct="%1.1f%%", explode=(0.1,0,0), shadow=True,colors=w)
# Out:
# ([<matplotlib.patches.Wedge at 0x7c88edfb6dd0>,
# ...
#  [Text(-1.1625063850265216, -0.2976220838119524, 'Regular Air'),
#   Text(1.0923094595086105, -0.12984623470862577, 'Delivery Truck'),
#   Text(0.8565422181339967, 0.6901705793165145, 'Express Air')],
#  [Text(-0.6781287245988041, -0.17361288222363885, '74.6%'),
#   Text(0.5958051597319692, -0.07082521893197768, '13.6%'),
#   Text(0.4672048462549072, 0.37645667962718965, '11.7%')])

# %%
sns.countplot(data=dataset,x='Ship Mode',hue='Product Category')
# Out:
# <Axes: xlabel='Ship Mode', ylabel='count'>

# %%
plt.savefig("Product Catergory wise ship mode")

# %%
sns.countplot(data=dataset,x='Customer Segment',hue='Product Category')
# Out:
# <Axes: xlabel='Customer Segment', ylabel='count'>

# %%
plt.figure(figsize=(20,10))

sns.countplot(data=dataset,x='Customer Segment',hue='Product Sub-Category')
plt.legend()

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=dataset[dataset["Product Category"]=="Office Supplies"],x='Customer Segment',hue='Product Sub-Category')
plt.legend()

# %%
#TIME SERIES ANALYSIS

dataset["Order Date Year"]=dataset["Order Date"].dt.year
dataset["Order Date Month"]=dataset["Order Date"].dt.month
dataset["Order Date Day"]=dataset["Order Date"].dt.day
dataset["Order Date Hour"]=dataset["Order Date"].dt.hour

dataset["Order Date Minute"]=dataset["Order Date"].dt.minute
dataset["Order Date Second"]=dataset["Order Date"].dt.second
dataset

dataset["Order Date Year"].value_counts()
# Out:
# Order Date Year
# 2013    3054
# 2012    2241
# 2011    2179
# 2010    1952
# Name: count, dtype: int64

# %%
sns.barplot(x="Product Category",y="Profit",data=dataset,estimator=sum)
# Out:
# <Axes: xlabel='Product Category', ylabel='Profit'>

# %%
dataset["State or Province"].value_counts()[:5]
dataset["State or Province"].value_counts().head(5)
# Out:
# State or Province
# California    1021
# Texas          646
# Illinois       584
# New York       574
# Florida        522
# Name: count, dtype: int64

# %%
sns.barplot(x="Product Category",y="Product Base Margin",data=dataset,estimator=sum)
# Out:
# <Axes: xlabel='Product Category', ylabel='Product Base Margin'>
